# %%
import pandas as pd
train_data = pd.read_csv('incidents_labelled.csv')
test_data = pd.read_csv('incidents_val.csv')

# %% [markdown]
# # Train Data

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5984 entries, 0 to 5983
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        5984 non-null   int64
#  1   year              5984 non-null   int64
#  2   month             5984 non-null   int64
#  3   day               5984 non-null   int64
#  4   country           5984 non-null   object
#  5   title             5984 non-null   object
#  6   text              5984 non-null   object
#  7   hazard-category   5984 non-null   object
#  8   product-category  5984 non-null   object
#  9   hazard            5984 non-null   object
#  10  product           5984 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 514.4+ KB

# %%
train_data.head(2)
# Out:
#    Unnamed: 0  year  month  day country                             title  \
# 0           0  1994      1    7      us  Recall Notification: FSIS-024-94
# 1           1  1994      3   10      us  Recall Notification: FSIS-033-94
#
#                                                 text hazard-category  \
# 0  Case Number: 024-94   \n            Date Opene...      biological
# 1  Case Number: 033-94   \n            Date Opene...      biological
#
#                product-category                  hazard         product
# 0  meat, egg and dairy products  listeria monocytogenes  smoked sausage
# 1  meat, egg and dairy products            listeria spp         sausage

# %%
train_data.value_counts('hazard-category')
# Out:
# hazard-category
# biological                        2020
# allergens                         1955
# foreign bodies                     769
# chemical                           498
# fraud                              411
# other hazard                       147
# packaging defect                    82
# organoleptic aspects                63
# food additives and flavourings      26
# migration                           13
# Name: count, dtype: int64

# %%
train_data.value_counts('product-category')
# Out:
# product-category
# meat, egg and dairy products                         1687
# cereals and bakery products                           778
# fruits and vegetables                                 655
# prepared dishes and snacks                            516
# nuts, nut products and seeds                          321
# soups, broths, sauces and condiments                  302
# seafood                                               297
# cocoa and cocoa preparations, coffee and tea          245
# ices and desserts                                     232
# confectionery                                         194
# herbs and spices                                      177
# dietetic foods, food supplements, fortified foods     172
# non-alcoholic beverages                               170
# alcoholic beverages                                    76
# other food product / mixed                             63
# food contact materials                                 25
# ...

# %%
pd.set_option('display.max_rows', None)
print(train_data['hazard'].value_counts())
pd.reset_option('display.max_rows')
# Out:
# hazard
# salmonella                                           751
# listeria monocytogenes                               727
# milk and products thereof                            614
# plastic fragment                                     281
# escherichia coli                                     275
# cereals containing gluten and products thereof       225
# peanuts and products thereof                         217
# eggs and products thereof                            214
# metal fragment                                       209
# soybeans and products thereof                        176
# glass fragment                                       145
# unauthorised substance ethylene oxide                114
# sulphur dioxide and sulphites                        102
# other                                                102
# inspection issues                                    101
# almond                                                72
# ...

# %%
pd.set_option('display.max_rows', None)
print(train_data['product'].value_counts())
pd.reset_option('display.max_rows')
# Out:
# product
# ice cream                                                                 191
# chicken based products                                                    147
# cakes                                                                     102
# cheese                                                                     85
# cookies                                                                    84
# ready to eat - cook meals                                                  81
# sausage                                                                    62
# salads                                                                     60
# ground beef                                                                55
# biscuits                                                                   54
# peanuts                                                                    53
# salmon                                                                     53
# ...

# %% [markdown]
# # Test Data

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 565 entries, 0 to 564
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  565 non-null    int64
#  1   year        565 non-null    int64
#  2   month       565 non-null    int64
#  3   day         565 non-null    int64
#  4   country     565 non-null    object
#  5   title       565 non-null    object
#  6   text        565 non-null    object
# dtypes: int64(4), object(3)
# memory usage: 31.0+ KB

# %%
test_data.head(2)
# Out:
#    Unnamed: 0  year  month  day country                             title  \
# 0           0  1994      5    5      us  Recall Notification: FSIS-017-94
# 1           1  1994      5   12      us  Recall Notification: FSIS-048-94
#
#                                                 text
# 0  Case Number: 017-94   \n            Date Opene...
# 1  Case Number: 048-94   \n            Date Opene...
